# %%
from tensorflow import keras
from keras.applications.vgg19 import VGG19
from tensorflow.keras.utils import load_img
from keras.applications.imagenet_utils import preprocess_input
import numpy as np
from keras.applications.vgg16 import decode_predictions

# %%
model = VGG19()       #It have Pre-trained model

model.summary()
# Out:
# ...
# 574710816/574710816 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
image = load_img("/content/drive/MyDrive/Colab Notebooks/CNN/Train_Data/elephant-jeremy-jowell-1280x881.jpg",target_size=(224,224))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image = np.array(image)

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
image.shape[0]
# Out:
# 224

# %%
image= image.reshape(1,image.shape[0],image.shape[1],image.shape[2])   #image.reshape(1,224,224,3)

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
image
# Out:
# array([[[[119, 139, 202],
#          [122, 143, 208],
#          [119, 140, 205],
#          ...,
#          [104, 120, 179],
#          [107, 125, 175],
#          [104, 121, 177]],
#
#         [[121, 140, 208],
#          [120, 141, 206],
#          [121, 142, 207],
#          ...,
#          [105, 122, 178],
#          [104, 120, 182],
#          [106, 123, 179]],
#
#         [[121, 142, 207],
#          [122, 143, 208],
#          [123, 144, 209],
#          ...,
#          [107, 124, 178],
#          [109, 126, 180],
#          [107, 124, 180]],
#
#         ...,
#
#         [[ 46,  33,  24],
#          [ 67,  49,  37],
#          [ 57,  38,  32],
#          ...,
#          [ 79,  57,  43],
#          [ 84,  68,  52],
#          [ 51,  38,  30]],
#
#         [[ 39,  24,  17],
#          [ 57,  37,  26],
#          [ 46,  27,  21],
#          ...,
#          [ 62,  46,  31],
#          [ 63,  47,  32],
#          [ 77,  57,  48]],
#
#         [[ 37,  28,  19],
# ...

# %%
pred = model.predict(image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
pred
# Out:
# array([[2.26267251e-11, 8.55147997e-14, 8.30991526e-12, 1.77187659e-12,
#         7.04378179e-12, 1.08747820e-11, 9.86949151e-12, 1.01165742e-11,
#         3.48498818e-13, 2.84259533e-10, 1.07744251e-14, 5.85643730e-14,
#         1.92388016e-14, 3.78766219e-13, 2.39314482e-13, 2.78564904e-13,
#         2.73094671e-13, 4.13074956e-13, 2.11829252e-13, 2.03376825e-13,
#         2.99311335e-12, 3.23654471e-11, 5.46780086e-11, 1.55512617e-10,
#         4.60283096e-11, 9.10803889e-14, 1.52560920e-13, 9.63335518e-14,
#         1.34462604e-13, 3.49451289e-13, 9.76283738e-14, 2.85308886e-14,
#         6.93073596e-14, 2.34347784e-11, 5.30442135e-10, 4.33784345e-12,
#         1.35421223e-11, 6.83082768e-13, 7.38612188e-14, 4.54264265e-11,
#         4.13820996e-13, 5.42827773e-13, 6.32724255e-12, 2.95256902e-10,
#         2.19053118e-12, 8.45137274e-13, 7.24390003e-13, 7.41636700e-12,
#         2.78594818e-08, 7.72978695e-11, 4.94021046e-10, 1.00195484e-06,
# ...

# %%
np.argmax(pred)
# Out:
# np.int64(101)

# %%
output = decode_predictions(pred)     #It shows 61% as tusker elephant (prediction)
output
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [[('n01871265', 'tusker', np.float32(0.6175851)),
#   ('n02504458', 'African_elephant', np.float32(0.31020325)),
#   ('n02504013', 'Indian_elephant', np.float32(0.07220904)),
#   ('n01704323', 'triceratops', np.float32(1.0019548e-06)),
#   ('n03000247', 'chain_mail', np.float32(8.353909e-07))]]
