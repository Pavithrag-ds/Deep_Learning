# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd #Working Directory
# Out:
# /root

# %% [markdown]
# # **Step 2: Change directory to YoloV5**

# %%
# %cd /content/yolov5   #Copy Path of yolov5 and paste here  #here we changed the location of working directory
# Out:
# /content/yolov5

# %% [markdown]
# # **Step 3: Install the Dependencies**

# %%
# !pip install -r requirements.txt   #from(requirements.txt)file.It will install all the required libraries

# %% [markdown]
# # **Step 4: Run Object Detection on Images. Provide the Image Path**

# %%
# !python detect.py --weights yolov5n.pt   #we get the weights from yolov5n model
# Out:
# detect: weights=['yolov5n.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-472-g7ca403a3 Python-3.12.13 torch-2.10.0+cpu CPU
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 126.0ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 1 tie, 107.5ms
# Speed: 2.0ms pre-process, 116.7ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
# !python detect.py --weights yolov5n.pt --source /content/yolov5/data/images/bus.jpg --save-txt --save-conf
# Out:
# detect: weights=['yolov5n.pt'], source=/content/yolov5/data/images/bus.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-472-g7ca403a3 Python-3.12.13 torch-2.10.0+cpu CPU
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# image 1/1 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 124.9ms
# Speed: 2.3ms pre-process, 124.9ms inference, 2.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp9
# 1 labels saved to runs/detect/exp9/labels

# %%
# !python detect.py --weights yolov5n.pt --source /content/Indian_street_picture.jpg
# Out:
# detect: weights=['yolov5n.pt'], source=/content/Indian_street_picture.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-472-g7ca403a3 Python-3.12.13 torch-2.10.0+cpu CPU
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# image 1/1 /content/Indian_street_picture.jpg: 448x640 12 persons, 1 car, 4 buss, 134.4ms
# Speed: 2.0ms pre-process, 134.4ms inference, 3.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp11

# %%
# !python detect.py --weights yolov5n.pt --source  /content/Indian_street_picture.jpg --save-txt --save-conf
# Out:
# detect: weights=['yolov5n.pt'], source=/content/Indian_street_picture.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-472-g7ca403a3 Python-3.12.13 torch-2.10.0+cpu CPU
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# image 1/1 /content/Indian_street_picture.jpg: 448x640 12 persons, 1 car, 4 buss, 123.3ms
# Speed: 2.0ms pre-process, 123.3ms inference, 2.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp12
# 1 labels saved to runs/detect/exp12/labels

# %% [markdown]
# We can also paste the videos path and use for detect
